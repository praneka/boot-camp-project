# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)

# %%
 
import requests
 
from datetime import datetime
 
apikey="70eec3832026d6db375972c5a382a6fe"
location=input("enter the city name:")
 
complete_link="https://api.openweathermap.org/data/2.5/weather?q="+location+"&appid="+apikey
api_link = requests.get(complete_link)
api_data = api_link.json()
 
temp_city =((api_data["main"]['temp']) - 273.15)
weather=api_data['weather'][0]["description"]
humidity=api_data["main"]['humidity']
date_time= datetime.now().strftime("%d %b %Y |  %I:%M:%S %p")
 
print("weather stats for - {} ||{}".format(location.upper(), date_time))
print("Temperature of the city:",temp_city,"deg C")
print("weather of the city:", weather)
print("Humidity of the city:", humidity,"%")
# Out:
# enter the city name:tirupur
# weather stats for - TIRUPUR ||23 Jun 2021 |  06:09:48 AM
# Temperature of the city: 30.640000000000043 deg C
# weather of the city: overcast clouds
# Humidity of the city: 44 %

# %%
with open('Untitled0.txt','r') as Untitled0:
      print>>Untitled0
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-014158a2ef92> in <module>()
# ----> 1 with open('Untitled0.txt','r') as Untitled0:
#       2       print>>Untitled0
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Untitled0.txt'
